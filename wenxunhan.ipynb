# %%
import pandas as pd
df = pd.DataFrame(data=None, index=None, columns=['时间','标题','股票代码','问询函类型','文件地址'], dtype=None, copy=False)

# %%
import requests
def downlourl(currentpage):
    url = "http://query.sse.com.cn/commonSoaQuery.do?siteId=28&sqlId=BS_GGLL&extGGLX=&stockcode=&channelId=10743%2C10744%2C10012&extGGDL=&order=createTime%7Cdesc%2Cstockcode%7Casc&isPagination=true&pageHelp.pageSize=15&pageHelp.pageNo=" + repr(currentpage) + "&pageHelp.beginPage=" + repr(currentpage) +"&pageHelp.cacheSize=1"
    return(url)

headers = {
    'Referer':'http://www.sse.com.cn/disclosure/credibility/supervision/inquiries/',
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}

for page in range(0,141):
    r = requests.get(downlourl(page), headers=headers)
    for i in r.json()['result']:
        Date = i['cmsOpDate']
        Title = i['docTitle']
        stockCode = i['stockcode']
        extWTFL = i['extWTFL']
        Type = i['docType']
        createTime = i['createTime']
        docURL = i['docURL']
        data = pd.DataFrame({'时间': Date,'标题':Title,'股票代码':stockCode,'问询函类型':extWTFL,'文件地址':i['docURL']},index =[0])
        df = df.append(data,ignore_index=True)
        print('完成爬取第%d页'%page) 
df

# %%
df.to_csv('问询函.csv')

# %%
import importlib
import sys
import random
from urllib.request import urlopen
from urllib.request import Request

from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal, LAParams
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
from pdfminer.pdfparser import PDFParser, PDFDocument
from io import StringIO
'''
 解析pdf 文本，保存到txt文件中
'''
importlib.reload(sys)

user_agent = ['Mozilla/5.0 (Windows NT 10.0; WOW64)', 'Mozilla/5.0 (Windows NT 6.3; WOW64)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:54.0) Gecko/20100101 Firefox/54.0',
              'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
              'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
              'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.95 Safari/537.36',
              'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; rv:11.0) like Gecko)',
              'Mozilla/5.0 (Windows; U; Windows NT 5.2) Gecko/2008070208 Firefox/3.0.1',
              'Mozilla/5.0 (Windows; U; Windows NT 5.1) Gecko/20070309 Firefox/2.0.0.3',
              'Mozilla/5.0 (Windows; U; Windows NT 5.1) Gecko/20070803 Firefox/1.5.0.12',
              'Opera/9.27 (Windows NT 5.2; U; zh-cn)',
              'Mozilla/5.0 (Macintosh; PPC Mac OS X; U; en) Opera 8.0',
              'Opera/8.0 (Macintosh; PPC Mac OS X; U; en)',
              'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.12) Gecko/20080219 Firefox/2.0.0.12 Navigator/9.0.0.6',
              'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Win64; x64; Trident/4.0)',
              'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0)',
              'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.2; .NET4.0C; .NET4.0E)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Maxthon/4.0.6.2000 Chrome/26.0.1410.43 Safari/537.1 ',
              'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.2; .NET4.0C; .NET4.0E; QQBrowser/7.3.9825.400)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:21.0) Gecko/20100101 Firefox/21.0 ',
              'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.92 Safari/537.1 LBBROWSER',
              'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0; BIDUBrowser 2.x)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.11 TaoBrowser/3.0 Safari/536.11']

def parse(_path):
    fp = open("8139644401384102.pdf", 'rb')  # rb以二进制读模式打开本地pdf文件
#     request = Request(url=_path, headers={'User-Agent': random.choice(user_agent)})  # 随机从user_agent列表中抽取一个元素
#     fp = urlopen(request) #打开在线PDF文档
    # 用文件对象来创建一个pdf文档分析器
    praser_pdf = PDFParser(fp)
    
    # 创建一个PDF文档
    doc = PDFDocument()

    # 连接分析器 与文档对象
    praser_pdf.set_document(doc)
    doc.set_parser(praser_pdf)

    # 提供初始化密码doc.initialize("123456")
    # 如果没有密码 就创建一个空的字符串
    doc.initialize()

    # 检测文档是否提供txt转换，不提供就忽略
    if not doc.is_extractable:
        print("123")
        raise PDFTextExtractionNotAllowed
    else:
        # 创建PDf资源管理器 来管理共享资源
        rsrcmgr = PDFResourceManager()

        # 创建一个PDF参数分析器
        laparams = LAParams()

        # 创建聚合器
        device = PDFPageAggregator(rsrcmgr, laparams=laparams)

        # 创建一个PDF页面解释器对象
        interpreter = PDFPageInterpreter(rsrcmgr, device)

        # 循环遍历列表，每次处理一页的内容
        # doc.get_pages() 获取page列表
        for page in doc.get_pages():
            # 使用页面解释器来读取
            interpreter.process_page(page)

            # 使用聚合器获取内容
            layout = device.get_result()

            # 这里layout是一个LTPage对象 里面存放着 这个page解析出的各种对象 一般包括LTTextBox, LTFigure, LTImage, LTTextBoxHorizontal 等等 想要获取文本就获得对象的text属性，
            for out in layout:
                # 判断是否含有get_text()方法，图片之类的就没有
                # if hasattr(out,"get_text"):
                if isinstance(out, LTTextBoxHorizontal):
                    results = out.get_text()
                    print("results: " + results)
url = "http://www.sse.com.cn/disclosure/credibility/supervision/inquiries/opinion/c/8139522232116590.pdf"
parse(url)

# %%
import io
from pdfminer.pdfinterp import PDFResourceManager, process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
user_agent = ['Mozilla/5.0 (Windows NT 10.0; WOW64)', 'Mozilla/5.0 (Windows NT 6.3; WOW64)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:54.0) Gecko/20100101 Firefox/54.0',
              'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
              'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
              'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.95 Safari/537.36',
              'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; rv:11.0) like Gecko)',
              'Mozilla/5.0 (Windows; U; Windows NT 5.2) Gecko/2008070208 Firefox/3.0.1',
              'Mozilla/5.0 (Windows; U; Windows NT 5.1) Gecko/20070309 Firefox/2.0.0.3',
              'Mozilla/5.0 (Windows; U; Windows NT 5.1) Gecko/20070803 Firefox/1.5.0.12',
              'Opera/9.27 (Windows NT 5.2; U; zh-cn)',
              'Mozilla/5.0 (Macintosh; PPC Mac OS X; U; en) Opera 8.0',
              'Opera/8.0 (Macintosh; PPC Mac OS X; U; en)',
              'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.12) Gecko/20080219 Firefox/2.0.0.12 Navigator/9.0.0.6',
              'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Win64; x64; Trident/4.0)',
              'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0)',
              'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.2; .NET4.0C; .NET4.0E)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Maxthon/4.0.6.2000 Chrome/26.0.1410.43 Safari/537.1 ',
              'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.2; .NET4.0C; .NET4.0E; QQBrowser/7.3.9825.400)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:21.0) Gecko/20100101 Firefox/21.0 ',
              'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.92 Safari/537.1 LBBROWSER',
              'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0; BIDUBrowser 2.x)',
              'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.11 TaoBrowser/3.0 Safari/536.11']
def convert_pdf(pdfFile, retstr):
    password = ''
    pagenos = set()
    maxpages = 0
    laparams = LAParams()
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)    
    process_pdf(rsrcmgr, device, pdfFile, pagenos, maxpages=maxpages, password=password, check_extractable=True)
    device.close()
    return retstr
logging.propagate = False 
logging.getLogger().setLevel(logging.ERROR)
request = Request(url='http://www.sse.com.cn/disclosure/credibility/supervision/inquiries/opinion/c/8135857143380427.pdf', headers={'User-Agent': random.choice(user_agent)})  # 随机从user_agent列表中抽取一个元素
pdfFile = urlopen(request) #打开在线PDF文档
# pdfFile = open('8139644401384102.pdf','rb')
retstr = io.StringIO()
retstr = convert_pdf(pdfFile, retstr)
print(retstr.getvalue())
pdfFile.close()

# %%
import pandas as pd
df = pd.DataFrame(data=None, index=None, columns=['时间','公司名称','股票代码','问询函类型','文件编号'], dtype=None, copy=False)

# %%
import requests
import json
def downlourl(currentpage):
    url = "http://www.szse.cn/api/report/ShowReport/data?SHOWTYPE=JSON&CATALOGID=main_wxhj&TABKEY=tab1&PAGENO="+repr(currentpage)+"&random=0.24989690833997513"
    return(url)

headers = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}
r = requests.get(url = "http://www.szse.cn/api/report/ShowReport/data?SHOWTYPE=JSON&CATALOGID=main_wxhj&TABKEY=tab1&PAGENO=0", headers=headers)
r.encoding = r.apparent_encoding
for page in range(0,101):
    r = requests.get(downlourl(page), headers=headers)
    r.encoding = r.apparent_encoding
    text = r.text
    jsonobj = json.loads(text)
    for i in jsonobj[0]['data']:
        Date = i['fhrq']
        Name = i['gsjc']
        stockCode = i['gsdm']
        extWTFL = i['hjlb']
        Type = i['hjlb']
        docURL = i['ck']
        docURL = docURL[60:-10]
        data = pd.DataFrame({'时间': Date,'公司名称':Name,'股票代码':stockCode,'问询函类型':extWTFL,'文件编号':docURL},index =[0])
        df = df.append(data,ignore_index=True)
        print('完成爬取第%d页'%page) 
df
# Out:
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第0页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第1页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第2页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第3页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第4页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第5页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第6页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第7页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第8页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第9页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第10页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第11页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第12页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第13页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第14页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第15页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第16页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第17页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第18页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第19页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第20页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第21页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第22页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第23页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第24页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第25页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第26页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第27页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第28页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第29页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第30页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第31页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第32页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第33页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第34页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第35页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第36页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第37页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第38页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第39页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第40页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第41页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第42页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第43页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第44页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第45页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第46页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第47页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第48页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第49页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第50页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第51页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第52页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第53页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第54页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第55页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第56页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第57页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第58页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第59页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第60页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第61页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第62页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第63页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第64页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第65页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第66页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第67页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第68页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第69页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第70页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第71页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第72页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第73页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第74页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第75页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第76页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第77页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第78页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第79页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第80页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第81页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第82页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第83页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第84页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第85页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第86页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第87页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第88页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第89页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第90页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第91页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第92页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第93页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第94页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第95页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第96页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第97页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第98页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第99页
# 完成爬取第100页
# 完成爬取第100页
# 完成爬取第100页
# 完成爬取第100页
# 完成爬取第100页
#               时间   公司名称    股票代码      问询函类型  \
# 0     2020-07-27   华联控股  000036        关注函
# 1     2020-07-24   东旭光电  000413        关注函
# 2     2020-07-24  *ST华讯  000687        关注函
# 3     2020-07-24    顺利办  000606        关注函
# 4     2020-07-23   海南海药  000566        关注函
# 5     2020-07-21  *ST华讯  000687        关注函
# 6     2020-07-17   智度股份  000676      年报问询函
# 7     2020-07-17  红 太 阳  000525        关注函
# 8     2020-07-17    新金路  000510        关注函
# 9     2020-07-17   招商蛇口  001979   许可类重组问询函
# 10    2020-07-10    太阳能  000591        关注函
# 11    2020-07-09  *ST金宇  000803      年报问询函
# 12    2020-07-09   双林生物  000403   许可类重组问询函
# 13    2020-07-08  红 太 阳  000525      年报问询函
# 14    2020-07-08   东旭蓝天  000040        关注函
# 15    2020-07-08  *ST天夏  000662      年报问询函
# 16    2020-07-07   中迪投资  000609        关注函
# 17    2020-07-06  深 赛 格  000058        关注函
# 18    2020-07-06  *ST长动  000835        关注函
# 19    2020-07-06  *ST长动  000835      年报问询函
# 20    2020-07-27   华联控股  000036        关注函
# 21    2020-07-24   东旭光电  000413        关注函
# 22    2020-07-24  *ST华讯  000687        关注函
# 23    2020-07-24    顺利办  000606        关注函
# 24    2020-07-23   海南海药  000566        关注函
# 25    2020-07-21  *ST华讯  000687        关注函
# 26    2020-07-17   智度股份  000676      年报问询函
# 27    2020-07-17  红 太 阳  000525        关注函
# 28    2020-07-17    新金路  000510        关注函
# 29    2020-07-17   招商蛇口  001979   许可类重组问询函
# ...          ...    ...     ...        ...
# 1975  2015-05-07   海虹控股  000503      年报问询函
# 1976  2015-05-07   烯碳新材  000511      年报问询函
# 1977  2015-05-07   北京文化  000802      年报问询函
# 1978  2015-05-05   上峰水泥  000672      年报问询函
# 1979  2015-05-04   零七股份  000007      年报问询函
# 1980  2015-05-04    黑芝麻  000716      年报问询函
# 1981  2015-05-02   新乡化纤  000949      年报问询函
# 1982  2015-04-30  *ST天化  000912  非许可类重组问询函
# 1983  2015-04-29   鑫茂科技  000836      年报问询函
# 1984  2015-04-27   经纬纺机  000666      年报问询函
# 1985  2015-04-27   山西三维  000755      年报问询函
# 1986  2015-04-24   华泽钴镍  000693      年报问询函
# 1987  2015-04-24   美利纸业  000815      年报问询函
# 1988  2015-04-23   茂业物流  000889  非许可类重组问询函
# 1989  2015-04-21   易食股份  000796      年报问询函
# 1990  2015-04-20   新大洲A  000571      年报问询函
# 1991  2015-04-20    索芙特  000662      年报问询函
# 1992  2015-04-16   金马股份  000980      年报问询函
# 1993  2015-04-11   恒天天鹅  000687  非许可类重组问询函
# 1994  2015-04-09   中天城投  000540      年报问询函
# 1995  2015-04-09   南风化工  000737      年报问询函
# 1996  2015-04-07   泸州老窖  000568      年报问询函
# 1997  2015-04-07   东北电气  000585      年报问询函
# 1998  2015-04-02   靖远煤电  000552      年报问询函
# 1999  2015-03-31   双汇发展  000895      年报问询函
# 2000  2015-03-18   景峰医药  000908      年报问询函
# 2001  2015-02-26   金浦钛业  000545      年报问询函
# 2002  2015-02-05   中国天楹  000035  非许可类重组问询函
# 2003  2014-12-10   中水渔业  000798  非许可类重组问询函
# 2004  2014-12-04   民生控股  000416  非许可类重组问询函
#
#                                                    文件编号
# 0                                    CDD00003658194.pdf
# 1                                    CDD00041358208.pdf
# 2                                    CDD00068758207.pdf
# 3                                    CDD00060658186.pdf
# 4                                    CDD00056658167.pdf
# 5                                    CDD00068758148.pdf
# 6                                    CDD00067658113.pdf
# 7                                    CDD00052558124.pdf
# 8                                    CDD00051058125.pdf
# 9                                    CDD00197958090.pdf
# 10                                   CDD00059158003.pdf
# 11                                   CDD00080357990.pdf
# 12                                   CDD00040357995.pdf
# 13                                   CDD00052557894.pdf
# 14                                   CDD00004057985.pdf
# 15                                   CDD00066257983.pdf
# 16                                   CDD00060957982.pdf
# 17                                   CDD00005857975.pdf
# 18                                   CDD00083557953.pdf
# 19                                   CDD00083557951.pdf
# 20                                   CDD00003658194.pdf
# 21                                   CDD00041358208.pdf
# 22                                   CDD00068758207.pdf
# 23                                   CDD00060658186.pdf
# 24                                   CDD00056658167.pdf
# 25                                   CDD00068758148.pdf
# 26                                   CDD00067658113.pdf
# 27                                   CDD00052558124.pdf
# 28                                   CDD00051058125.pdf
# 29                                   CDD00197958090.pdf
# ...                                                 ...
# 1975  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%B5%B7%E...
# 1976  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E9%93%B6%E...
# 1977  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E5%8C%97%E...
# 1978  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E7%94%98%E...
# 1979  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%B7%B1%E...
# 1980  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E5%8D%97%E...
# 1981  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%96%B0%E...
# 1982                                CDD00091234429.docx
# 1983  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E5%A4%A9%E...
# 1984  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E7%BB%8F%E...
# 1985  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E5%B1%B1%E...
# 1986  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%88%90%E...
# 1987  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E4%B8%AD%E...
# 1988                                CDD00088934324.docx
# 1989  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%98%93%E...
# 1990  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%96%B0%E...
# 1991  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E7%B4%A2%E...
# 1992  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E9%BB%84%E...
# 1993                                CDD00068734158.docx
# 1994  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E4%B8%AD%E...
# 1995  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E5%8D%97%E...
# 1996  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%B3%B8%E...
# 1997  XXB_CDD_000585%E4%B8%9C%E5%8C%97%E7%94%B5%E6%B...
# 1998  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E7%94%98%E...
# 1999  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%B2%B3%E...
# 2000  XXB_CDD_%E5%85%B3%E4%BA%8E%E5%AF%B9%E6%B9%96%E...
# 2001  XXB_CDD_000545%E9%87%91%E6%B5%A6%E9%92%9B%E4%B...
# 2002                                CDD00003533685.docx
# 2003                                CDD00079833287.docx
# 2004                                CDD00041633257.docx
#
# [2005 rows x 5 columns]

# %%
str = "<a href='javascript:void(0)' encode-open='/UpFiles/fxklwxhj/CDD00060658186.pdf'>详细内容</a>"
str = str[60:-10]
print(str)
# Out:
# CDD00060658186.pdf

# %%
df.to_csv('深交所问询函.csv')
