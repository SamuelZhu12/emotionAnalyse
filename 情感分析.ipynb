# %%
import pandas as pd
f = open('情感词汇本体.csv',encoding="utf-8")
df = pd.read_csv(f)
df

# %%
##计算文本情绪值
import jieba
import time
def emotion_caculate(text):
    positive = 0
    negative = 0
    anger = 0
    disgust = 0
    fear = 0
    sad = 0
    surprise = 0
    good = 0
    happy = 0
    wordlist = jieba.lcut(text)
    wordset = set(wordlist)
    wordfreq = []
    for word in wordset:
        freq = wordlist.count(word)
        if word in Positive:
            positive += freq
        if word in Negative:
            print(word)
            negative += freq
        if word in Anger:
            anger +=freq
        if word in Disgust:
            disgust += freq
        if word in Fear:
            fear += freq
        if word in Sad:
            sad += freq
        if word in Surprise:
            surprise += freq
        if word in Good:
            good += freq
        if word in Happy:
            happy += freq
    emotion_info = {
        'length': len(wordlist),
        'positive': positive,
        "negative": negative,
        'anger':anger,
        'disgust':disgust,
        'fear':fear,
        'good':good,
        'sadness':sad,
        'surprise':surprise,
        'happy':happy
    }
    indexs = ['length','positive','negative','anger','disgust','fear','good','sadness','surprise','happy']
    return pd.Series(emotion_info, index = indexs)
emotion_caculate(text = '这个国家再对这些制造假冒伪劣食品药品的人手软的话，那后果真的会相当糟糕。坐牢？从快判个死刑')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\56268\AppData\Local\Temp\jieba.cache
# Loading model cost 0.845 seconds.
# Prefix dict has been built successfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e2f729ea387e> in <module>()
#      50     indexs = ['length','positive','negative','anger','disgust','fear','good','sadness','surprise','happy']
#      51     return pd.Series(emotion_info, index = indexs)
# ---> 52 emotion_caculate(text = '这个国家再对这些制造假冒伪劣食品药品的人手软的话，那后果真的会相当糟糕。坐牢？从快判个死刑')
#
# <ipython-input-2-e2f729ea387e> in emotion_caculate(text)
#      17     for word in wordset:
#      18         freq = wordlist.count(word)
# ---> 19         if word in Positive:
#      20             positive += freq
#      21         if word in Negative:
#
# NameError: name 'Positive' is not defined

# %%
start = time.time()
emotion_df = df_small['review'].apply(emotion_caculate)
end = time.time()
print(end-start)
emotion_df
# Out:
# 恐惧
# 入侵
# 完蛋
# 摧毁
# 开心
# 失业
# 好事
# 教条主义
# 未必
# 没用
# HC
# 矜持
# 搔首弄姿
# 刺激
# 不是
# 任性
# 不外
# 困难
# 夸耀
# 贫困
# 猖狂
# 不是
# 随心所欲
# 不是
# 口口声声
# 开心
# 离奇
# 不是
# 玄妙
# 重创
# 痛苦
# 消息
# 对不住
# 难以
# 指使
# 末路
# 1.632633924484253
#     length  positive  negative  anger  disgust  fear  good  sadness  surprise  \
# 0       58         0         0      0        0     0     0        0         0
# 1       68         1         4      0        2     1     1        1         0
# 2       12         2         0      0        0     0     2        0         0
# 3       62         1         0      0        0     0     1        0         0
# 4       52         1         0      0        0     0     1        0         0
# 5       84         1         0      0        0     0     0        0         0
# 6       66         5         0      0        0     0     4        0         0
# 7       73         5         1      0        1     0     1        0         0
# ...

# %%
output_df = pd.concat([df_small, emotion_df], axis = 1)
output_df
